# %%
import os
import pandas as pd
import pydot
from IPython.display import SVG
from pycausal.pycausal import pycausal as pc

# %%
df = pd.read_csv("static/cardiotocography3/data_file.csv")

# %%
df.head()
# Out:
#      b     e  LBE   LB  AC  FM  UC  ASTV  MSTV  ALTV    ...     Width  Min  \
# 0  240   357  120  120   0   0   0    73   0.5    43    ...        64   62
# 1    5   632  132  132   4   0   4    17   2.1     0    ...       130   68
# 2  177   779  133  133   2   0   5    16   2.1     0    ...       130   68
# 3  411  1192  134  134   2   0   6    16   2.4     0    ...       117   53
# 4  533  1147  132  132   4   0   5    16   2.4     0    ...       117   53
#
#    Max  Nmax  Nzeros  Mode  Mean  Median  Variance  Tendency
# 0  126     2       0   120   137     121        73         1
# 1  198     6       1   141   136     140        12         0
# 2  198     5       1   141   135     138        13         0
# 3  170    11       0   137   134     137        13         1
# 4  170     9       0   137   136     138        11         1
#
# [5 rows x 25 columns]

# %%
Y = pd.read_csv("static/cardiotocography3/target.csv")
Y.head()
# Out:
#    CLASS
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0

# %%
df = df.join(Y)

# %%
df.head()
# Out:
#      b     e  LBE   LB  AC  FM  UC  ASTV  MSTV  ALTV  ...    Min  Max  Nmax  \
# 0  240   357  120  120   0   0   0    73   0.5    43  ...     62  126     2
# 1    5   632  132  132   4   0   4    17   2.1     0  ...     68  198     6
# 2  177   779  133  133   2   0   5    16   2.1     0  ...     68  198     5
# 3  411  1192  134  134   2   0   6    16   2.4     0  ...     53  170    11
# 4  533  1147  132  132   4   0   5    16   2.4     0  ...     53  170     9
#
#    Nzeros  Mode  Mean  Median  Variance  Tendency  CLASS
# 0       0   120   137     121        73         1      1
# 1       1   141   136     140        12         0      0
# 2       1   141   135     138        13         0      0
# 3       0   137   134     137        13         1      0
# 4       0   137   136     138        11         1      0
#
# [5 rows x 26 columns]

# %%
df.to_csv("datafile.csv", index = False)

# %%
pc = pc()
pc.start_vm()

# %%
from pycausal import search as s
tetrad = s.tetradrunner()
tetrad.run(algoId = 'fges', dfs = df, scoreId = 'sem-bic', dataType = 'continuous',
penaltyDiscount = 2, maxDegree = -1, faithfulnessAssumed = True, verbose = True)

# %%
tetrad.getNodes()
# Out:
# [u'b',
#  u'e',
#  u'LBE',
#  u'LB',
#  u'AC',
#  u'FM',
#  u'UC',
#  u'ASTV',
#  u'MSTV',
#  u'ALTV',
#  u'MLTV',
#  u'DL',
#  u'DS',
#  u'DP',
#  u'DR',
#  u'Width',
#  u'Min',
#  u'Max',
#  u'Nmax',
#  u'Nzeros',
#  u'Mode',
#  u'Mean',
#  u'Median',
#  u'Variance',
#  u'Tendency',
#  u'CLASS']

# %%
edges = tetrad.getEdges()

# %%
# Out:
# 'DP --> LB'

# %%
src = str(dot_str).replace('\"', "").splitlines()

# %%
''.join(src[1].split("];")) + str(', color')
# Out:
# ' DP -> LB [arrowtail=none, arrowhead=normal , color'

# %%
import pydot
from IPython.display import SVG
dot_str = pc.tetradGraphToDot(tetrad.getTetradGraph())
graphs = pydot.graph_from_dot_data(dot_str)
svg_str = graphs[0].create_svg()
SVG(svg_str)
